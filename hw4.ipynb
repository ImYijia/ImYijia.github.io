# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/bcaffo/ds4bme_intro/master/data/kirby21.csv")
df = df.drop(['Unnamed: 0', 'rawid', 'min', 'max', 'mean', 'std'],\
             axis = 1)
df.head(5)
# Out:
#                roi  volume  type  level   id      icv      tbv
# 0  Telencephalon_L  531111     1      1  127  1378295  1268519
# 1  Telencephalon_R  543404     1      1  127  1378295  1268519
# 2   Diencephalon_L    9683     1      1  127  1378295  1268519
# 3   Diencephalon_R    9678     1      1  127  1378295  1268519
# 4    Mesencephalon   10268     1      1  127  1378295  1268519

# %%
pip install plotly
# Out:
# ...
#      |████████████████████████████████| 27.7 MB 47 kB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import plotly.graph_objects as go
import urllib, json

# %%
fig = px.bar(df, x = "id", y = "volume", color = "roi")
fig.show()
# Out:
# <div>                            <div id="ac6ab7ec-3dad-414b-bb32-7ef1511ff205" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac6ab7ec-3dad-414b-bb32-7ef1511ff205")) {                    Plotly.newPlot(                        "ac6ab7ec-3dad-414b-bb32-7ef1511ff205",                        [{"alignmentgroup":"True","hovertemplate":"roi=Telencephalon_L<br>id=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"Telencephalon_L","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Telencephalon_L","offsetgroup":"Telencephalon_L","orientation":"v","showlegend":true,"textposition":"auto","x":[127,142,239,346,422,492,501,505,656,679,742,800,814,815,849,906,913,916,934,959],"xaxis":"x","y":[531111,545603,483107,558849,509945,538936,506151,457862,55165
# ...

# %%
icv = df.groupby(['id']).volume.sum().reset_index().rename(columns = {'volume' : 'icv'})
dat = pd.merge(df, icv, on = 'id')
dat = dat.assign(comp = df.volume / df.icv)
dat.head()
# Out:
#                roi  volume  type  level   id    icv_x      tbv     icv_y  \
# 0  Telencephalon_L  531111     1      1  127  1378295  1268519  13783255
# 1  Telencephalon_R  543404     1      1  127  1378295  1268519  13783255
# 2   Diencephalon_L    9683     1      1  127  1378295  1268519  13783255
# 3   Diencephalon_R    9678     1      1  127  1378295  1268519  13783255
# 4    Mesencephalon   10268     1      1  127  1378295  1268519  13783255
#
#        comp
# 0  0.385339
# 1  0.394258
# 2  0.007025
# 3  0.007022
# 4  0.007450

# %%
label_list = ['1378295', '1268519', 'Telencephalon_L', 'Telencephalon_R']
# 1378295:0; 1268519:1; Telencephalon_L:2; Telencephalon_R:3
source = [2, 3]
target = [0, 1]
count = [1, 1]

fig = go.Figure(data=[go.Sankey(
    node = {"label": label_list},
    link = {"source": source, "target": target, "value": count}
    )])
fig.show()
# Out:
# <div>                            <div id="3ef69c90-14bc-48a5-833a-7716f051210e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ef69c90-14bc-48a5-833a-7716f051210e")) {                    Plotly.newPlot(                        "3ef69c90-14bc-48a5-833a-7716f051210e",                        [{"link":{"source":[2,3],"target":[0,1],"value":[1,1]},"node":{"label":["1378295","1268519","Telencephalon_L","Telencephalon_R"]},"type":"sankey"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":
# ...
